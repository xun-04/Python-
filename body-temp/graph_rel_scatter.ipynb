# %% [markdown]
# # 散点图
#
# ## 简介

# %% [markdown]
# ## 气泡图
#
# 气泡图是散点图的一种变体，其中每个点的大小表示一个额外的维度。气泡图通常用于可视化三个维度的数据，其中两个维度由 x 和 y 坐标表示，第三个维度由气泡的大小表示。气泡图可以帮助我们更好地理解数据的分布和关系。

# %%
import seaborn as sns
import seaborn.objects as so

# Load the penguins dataset
penguins = sns.load_dataset("penguins")

so.Plot(
    data=penguins, 
    x="bill_length_mm", y="bill_depth_mm",
    color="species", 
    pointsize="body_mass_g",
).add(so.Dot())
